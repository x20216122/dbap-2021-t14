# %%
import psycopg2
import pymongo

print('Imported packages successfully.')
# Out:
# Imported packages successfully.

# %%
def connect(db="dbap-2021-t14"):
    dbConnection = psycopg2.connect(
        user = "postgres",
        password = "gmd5PNXNhjGvjp",
        host = "178.62.41.209",
        port = "5432",
        database = db)
    dbConnection.set_isolation_level(0) # AUTOCOMMIT
    return dbConnection

# %%
connect()
# Out:
# <connection object at 0x000002D0118596A0; dsn: 'user=postgres password=xxx dbname=dbap-2021-t14 host=178.62.41.209 port=5432', closed: 0>

# %%
myDocumentList = {}
myclient = pymongo.MongoClient("mongodb://mongo:gmd5PNXNhjGvjp@178.62.41.209:27017")
mydb = myclient["gdp"]
#mycol = mydb[""]

#myquery = {  }

#mydoc = mycol.find(myquery)

#for x in mydoc:
 # print(x)

for name in mydb.list_mycol_names():
    for doc in mycol.find():
        myDocumentList.add(doc)
        
print(myDocumentList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7b2d5588051c> in <module>
#      11  # print(x)
#      12
# ---> 13 for name in mydb.list_mycol_names():
#      14     for doc in mycol.find():
#      15         myDocumentList.add(doc)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3438         """
#    3439         if "." not in self.__name:
# -> 3440             raise TypeError("'Collection' object is not callable. If you "
#    3441                             "meant to call the '%s' method on a 'Database' "
#    3442                             "object it is failing because no such method "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'list_mycol_names' method on a 'Database' object it is failing because no such method exists.

# %%
# importing module
from pymongo import MongoClient

# creation of MongoClient
client=MongoClient()

# Connect with the portnumber and host
client = MongoClient("mongodb://mongo:gmd5PNXNhjGvjp@178.62.41.209:27017")

# Access database
mydatabase = client.gdp


db = client.mydatabase
  
# Created or Switched to collection names: myTable
collection = db.myTable
  
# To find() all the entries inside collection name 'myTable'
cursor = collection.find()
for record in cursor:
    print(record)

# %%
from pymongo import MongoClient
  
gdp = {}
    
try:
    conn = MongoClient("mongodb://mongo:gmd5PNXNhjGvjp@178.62.41.209:27017")
    print("Connected successfully!!!")
except:  
    print("Could not connect to MongoDB")
  
db = conn["gdp"]
  
    gdp[record['id']] = record

  
# To find() all the entries inside collection name 'myTable'    
for collectionName in db.list_collection_names():
    collection = db[collectionName]
    cursor = collection.find()
    for record in cursor:
        gdp[cursor] = record
# Out:
# Connected successfully!!!

# %%
print (gdp)
# Out:
# {<pymongo.cursor.Cursor object at 0x000002008717AD30>: {'_id': ObjectId('608417840eba550f5f5f1cdf'), '0': nan, '1': 800000044.4444441, '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': 25605249381.7597, '8': nan, '9': nan, '10': nan, '11': 23764139321.3126, '12': 9169983885.71185, '13': nan, '14': 260750008.0, '15': 15960106680.6732, '16': 269818988.259263, '17': 410321785.631059, '18': 5386054619.349871, '19': nan, '20': nan, '21': 266666666.66666698, '22': nan, '23': nan, '24': 36193826.1234775, '25': 107566650.637987, '26': 539491477.320156, '27': 21211892259.9904, '28': nan, '29': nan, '30': nan, '31': 41613969.0506064, '32': 142025069.461676, '33': 49377522896.702995, '34': nan, '35': 14480556571.5476, '36': nan, '37': 5982347826.08696, '38': 59708343488.5043, '39': 921063266.4455211, '40': 782384527.813649, '41': 2881545272.72727, '42': 185693724.845363, '43': 5973366666.66667, '44': nan, '45': nan, '46': 542578367.242598, '47': 2470264539.67836, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57